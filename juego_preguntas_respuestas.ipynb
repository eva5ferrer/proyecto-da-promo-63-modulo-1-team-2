# %% [markdown]
# # Juego de Preguntas y Respuestas de Geografía

# %%
quiz_geo = {
    "preguntas": [
        {"pregunta": "¿Cuál es la capital de Francia?",
         "opciones": {"A": "Marsella", "B": "París", "C": "Lyon"},
         "correcta": "B"},

        {"pregunta": "¿Qué país tiene la mayor superficie del mundo?",
         "opciones": {"A": "Canadá", "B": "China", "C": "Rusia"},
         "correcta": "C"},

        {"pregunta": "¿En qué continente está Egipto?",
         "opciones": {"A": "África", "B": "Asia", "C": "Europa"},
         "correcta": "A"},

        {"pregunta": "¿Cuál es la capital de Japón?",
         "opciones": {"A": "Osaka", "B": "Tokio", "C": "Kioto"},
         "correcta": "B"},

        {"pregunta": "¿Qué océano baña las costas de Chile?",
         "opciones": {"A": "Atlántico", "B": "Índico", "C": "Pacífico"},
         "correcta": "C"},

        {"pregunta": "¿Cuál es la capital de Australia?",
         "opciones": {"A": "Sídney", "B": "Canberra", "C": "Melbourne"},
         "correcta": "B"},

        {"pregunta": "¿Qué cordillera separa Europa de Asia en gran parte?",
         "opciones": {"A": "Andes", "B": "Urales", "C": "Alpes"},
         "correcta": "B"},

        {"pregunta": "¿Cuál es el desierto más grande del mundo (caliente)?",
         "opciones": {"A": "Gobi", "B": "Sahara", "C": "Kalahari"},
         "correcta": "B"},

        {"pregunta": "¿Qué país NO tiene costa marítima?",
         "opciones": {"A": "Bolivia", "B": "Perú", "C": "Ecuador"},
         "correcta": "A"},

        {"pregunta": "¿Cuál es la capital de Canadá?",
         "opciones": {"A": "Toronto", "B": "Ottawa", "C": "Montreal"},
         "correcta": "B"},

        {"pregunta": "¿Cuál es la montaña más alta del mundo?",
         "opciones": {"A": "K2", "B": "Everest", "C": "Aconcagua"},
         "correcta": "B"},

        {"pregunta": "¿Qué mar está entre Europa y África?",
         "opciones": {"A": "Mar Mediterráneo", "B": "Mar Rojo", "C": "Mar Negro"},
         "correcta": "A"},

        {"pregunta": "¿Cuál es la capital de Argentina?",
         "opciones": {"A": "Córdoba", "B": "Buenos Aires", "C": "Rosario"},
         "correcta": "B"},

        {"pregunta": "¿Qué país tiene forma de “bota”?",
         "opciones": {"A": "Grecia", "B": "Italia", "C": "Portugal"},
         "correcta": "B"},

        {"pregunta": "¿Qué océano está entre América y Europa?",
         "opciones": {"A": "Atlántico", "B": "Pacífico", "C": "Índico"},
         "correcta": "A"},

        {"pregunta": "¿Cuál es la capital de España?",
         "opciones": {"A": "Barcelona", "B": "Sevilla", "C": "Madrid"},
         "correcta": "C"},

        {"pregunta": "¿Cuál es la capital de Italia?",
         "opciones": {"A": "Milán", "B": "Roma", "C": "Nápoles"},
         "correcta": "B"},

        {"pregunta": "¿Cuál es la capital de Portugal?",
         "opciones": {"A": "Lisboa", "B": "Oporto", "C": "Braga"},
         "correcta": "A"},

        {"pregunta": "¿Cuál es la capital de Alemania?",
         "opciones": {"A": "Berlín", "B": "Múnich", "C": "Hamburgo"},
         "correcta": "A"},

        {"pregunta": "¿Cuál es la capital de Brasil?",
         "opciones": {"A": "Brasilia", "B": "Río de Janeiro", "C": "São Paulo"},
         "correcta": "A"},

        {"pregunta": "¿Qué estrecho separa España de Marruecos?",
         "opciones": {"A": "Bósforo", "B": "Gibraltar", "C": "Magallanes"},
         "correcta": "B"},

        {"pregunta": "¿Qué río pasa por Londres?",
         "opciones": {"A": "Sena", "B": "Támesis", "C": "Danubio"},
         "correcta": "B"},

        {"pregunta": "¿Cuál es la capital de México?",
         "opciones": {"A": "Guadalajara", "B": "Monterrey", "C": "Ciudad de México"},
         "correcta": "C"},

        {"pregunta": "¿Qué país tiene la capital Nairobi?",
         "opciones": {"A": "Kenia", "B": "Tanzania", "C": "Uganda"},
         "correcta": "A"},

        {"pregunta": "¿Cuál es la capital de Estados Unidos?",
         "opciones": {"A": "Nueva York", "B": "Washington D. C.", "C": "Los Ángeles"},
         "correcta": "B"},

        {"pregunta": "¿Qué país tiene como capital Bangkok?",
         "opciones": {"A": "Tailandia", "B": "Vietnam", "C": "Camboya"},
         "correcta": "A"},

        {"pregunta": "¿Qué cordillera está en Sudamérica?",
         "opciones": {"A": "Himalaya", "B": "Andes", "C": "Rocosas"},
         "correcta": "B"},

        {"pregunta": "¿Cuál es la capital de Egipto?",
         "opciones": {"A": "El Cairo", "B": "Alejandría", "C": "Giza"},
         "correcta": "A"},

        {"pregunta": "¿Qué país tiene la capital Bogotá?",
         "opciones": {"A": "Colombia", "B": "Venezuela", "C": "Ecuador"},
         "correcta": "A"},

        {"pregunta": "¿Cuál es la capital de Suecia?",
         "opciones": {"A": "Oslo", "B": "Estocolmo", "C": "Copenhague"},
         "correcta": "B"},

        {"pregunta": "¿Qué país tiene la capital Copenhague?",
         "opciones": {"A": "Dinamarca", "B": "Bélgica", "C": "Suiza"},
         "correcta": "A"},

        {"pregunta": "¿Cuál es la capital de Perú?",
         "opciones": {"A": "Cusco", "B": "Arequipa", "C": "Lima"},
         "correcta": "C"},

        {"pregunta": "¿Qué país tiene la capital Wellington?",
         "opciones": {"A": "Australia", "B": "Nueva Zelanda", "C": "Fiyi"},
         "correcta": "B"},

        {"pregunta": "¿Qué isla es la más grande del mundo?",
         "opciones": {"A": "Groenlandia", "B": "Borneo", "C": "Islandia"},
         "correcta": "A"},

        {"pregunta": "¿Cuál es la capital de Noruega?",
         "opciones": {"A": "Oslo", "B": "Estocolmo", "C": "Helsinki"},
         "correcta": "A"},

        {"pregunta": "¿Cuál es la capital de Finlandia?",
         "opciones": {"A": "Riga", "B": "Helsinki", "C": "Tallin"},
         "correcta": "B"},

        {"pregunta": "¿Cuál es la capital de Bélgica?",
         "opciones": {"A": "Bruselas", "B": "Ámsterdam", "C": "Luxemburgo"},
         "correcta": "A"},

        {"pregunta": "¿Cuál es la capital de Suiza?",
         "opciones": {"A": "Ginebra", "B": "Zúrich", "C": "Berna"},
         "correcta": "C"},

        {"pregunta": "¿Cuál es la capital de Austria?",
         "opciones": {"A": "Viena", "B": "Praga", "C": "Budapest"},
         "correcta": "A"},

        {"pregunta": "¿Cuál es la capital de Irlanda?", 
         "opciones": {"A": "Dublín", "B": "Belfast", "C": "Cork"}, 
         "correcta": "A"},

        {"pregunta": "¿Cuál es la capital de Islandia?",
         "opciones": {"A": "Reikiavik", "B": "Oslo", "C": "Helsinki"},
         "correcta": "A"},

        {"pregunta": "¿Cuál es el río más largo del mundo?",
         "opciones": {"A": "Amazonas", "B": "Nilo", "C": "Yangtsé"},
         "correcta": "B"},

        {"pregunta": "¿Qué continente tiene más países?",
         "opciones": {"A": "África", "B": "Europa", "C": "Asia"},
         "correcta": "A"},

        {"pregunta": "¿Qué cordillera recorre gran parte de Sudamérica?",
         "opciones": {"A": "Rocosas", "B": "Andes", "C": "Himalaya"},
         "correcta": "B"},

        {"pregunta": "¿Qué país tiene forma de bota?",
         "opciones": {"A": "Italia", "B": "Grecia", "C": "Portugal"},
         "correcta": "A"},

        {"pregunta": "¿Qué mar separa Europa de África?",
         "opciones": {"A": "Mar Negro", "B": "Mar Rojo", "C": "Mar Mediterráneo"},
         "correcta": "C"},

        {"pregunta": "¿Qué país NO tiene salida al mar?",
         "opciones": {"A": "Bolivia", "B": "Chile", "C": "Perú"},
         "correcta": "A"},

        {"pregunta": "¿Cuál es la capital de Croacia?",
         "opciones": {"A": "Split", "B": "Zagreb", "C": "Dubrovnik"},
         "correcta": "B"},
        
        {"pregunta": "¿Cuál es la capital de República Checa?",
         "opciones": {"A": "Brno", "B": "Praga", "C": "Ostrava"},
         "correcta": "B"},

        {"pregunta": "¿Qué océano separa América de Europa?",
         "opciones": {"A": "Pacífico", "B": "Atlántico", "C": "Índico"},
         "correcta": "B"}, ]
}

# %%
len(quiz_geo["preguntas"])
# Out:
# 50

# %%
import random

# %%
def pregunta_aleatoria(lista_preguntas, usadas):
    disponibles = [p for p in lista_preguntas if p["pregunta"] not in usadas]
    if not disponibles:
        return None
    return random.choice(disponibles)

#Sirve para: elegir una pregunta al azar y evitar que se repitan las peguntas en la partida

# %%
def mostrar_pregunta(data):
    #Muestra el texto de la pregunta y las opciones A, B y C.
    print(data["pregunta"])
    for letra in ("A", "B", "C"):
        print(f"  {letra}) {data['opciones'][letra]}")

# %%
def pedir_respuesta():
    #Pide al usuario A, B o C y valida la entrada.
    #Devuelve la letra en mayúscula.
    
    while True:
        r = input("Elige A, B, C o escribe 'salir': ").strip().upper()
        if r== "SALIR":
            return "salir"
        elif r in ("A", "B", "C"):
            return r
        else:
            print(" Entrada inválida. Escribe A, B o C.")

# %%
def jugar_una_partida(quiz_geo):
    preguntas = quiz_geo["preguntas"]
    usadas = set()

    correctas = 0
    incorrectas = 0

    print(" QUIZ DE GEOGRAFÍA (A/B/C)\n")
    print("Reglas: ganas con 5 correctas o pierdes con 3 fallos.\n")

    while correctas < 5 and incorrectas < 3:
        data = pregunta_aleatoria(preguntas, usadas)

        if data is None:
            usadas.clear()
            data= pregunta_aleatoria(preguntas, usadas)

        usadas.add(data["pregunta"])

        mostrar_pregunta(data)
        r = pedir_respuesta()
        if r == "salir":
            print("\n Has salido del juego. ¡Hasta luego!")
            return

        if r == data["correcta"]:
            correctas += 1
            print(" Correcto\n")
        else:
            incorrectas += 1
            letra = data["correcta"]
            texto = data["opciones"][letra]
            print(f" Incorrecto. Era {letra}) {texto}\n")

        print(f" Correctas: {correctas} |  Incorrectas: {incorrectas}\n")

    if correctas == 5:
        print(" ¡HAS GANADO! Llegaste a 5 respuestas correctas.")
    else:
        print(" HAS PERDIDO. Llegaste a 3 respuestas incorrectas.")

# %%
def preguntar_repetir():
   
    # Pregunta al usuario si quiere volver a jugar.
    #Acepta 'si' devuelve true o 'no' devuelve false.
    
    while True:
        r = input("¿Quieres volver a jugar? (si / no): ").strip().lower()

        if r == "si":
            return True
        if r == "no":
            return False

        print(" Responde solo con 'si' o 'no'.")

# %%
def iniciar_juego(quiz_geo):
    print(" BIENVENIDO AL QUIZ DE GEOGRAFÍA")

    
    jugar_una_partida(quiz_geo)
    if not preguntar_repetir():
        print("\nGracias por jugar. ¡Hasta la próxima!")

# %%
iniciar_juego(quiz_geo)
# Out:
#  BIENVENIDO AL QUIZ DE GEOGRAFÍA
#  QUIZ DE GEOGRAFÍA (A/B/C)
#
# Reglas: ganas con 5 correctas o pierdes con 3 fallos.
#
# ¿Qué océano está entre América y Europa?
#   A) Atlántico
#   B) Pacífico
#   C) Índico
#
#  Has salido del juego. ¡Hasta luego!
#
# Gracias por jugar. ¡Hasta la próxima!
